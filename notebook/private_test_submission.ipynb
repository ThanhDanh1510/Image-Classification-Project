# %% [markdown]
# # Private Test Inference
#
# Notebook nay dung checkpoint da train san de du doan tat ca anh trong folder `images/` va sinh `submission.csv`.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if not (ROOT / 'src').exists():
    ROOT = ROOT.parent

SRC_DIR = ROOT / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

from image_classification.inference import generate_submission

# %%
IMAGES_DIR = ROOT / 'images'
OUTPUT_PATH = ROOT / 'submission.csv'
PARAMS_PATH = ROOT / 'params.yaml'

submission_path = generate_submission(
    image_dir=IMAGES_DIR,
    output_path=OUTPUT_PATH,
    params_path=PARAMS_PATH,
)
print(f'Submission saved to: {submission_path}')

# %%
import pandas as pd

submission_df = pd.read_csv(OUTPUT_PATH)
submission_df.head(10)
